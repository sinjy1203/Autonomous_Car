# %%
# %cd /content/drive/Othercomputers/내 노트북/GIGACHA/yolov5
# Out:
# /content/drive/Othercomputers/내 노트북/GIGACHA/yolov5

# %%
# %%capture
# !pip install -r requirements.txt

# %%
import yaml

with open('./parking/data.yaml', 'r') as f:
  data = yaml.safe_load(f)

# print(data)

data['train'] = '/content/drive/Othercomputers/내 노트북/GIGACHA/yolov5/parking/images'
data['val'] = '/content/drive/Othercomputers/내 노트북/GIGACHA/yolov5/parking/images'

with open('./parking/data.yaml', 'w') as f:
  yaml.dump(data, f)

# %%
/content/drive/Othercomputers/내 노트북/GIGACHA/yolov5/parking/images

# %%
# !python train.py --data ./parking/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --batch 8 --epochs 200 --name parking
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=./parking/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=parking, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/content/drive/Othercomputers/내': No such file or directory
# YOLOv5 🚀 2023-3-5 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
